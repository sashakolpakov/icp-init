# %%
#
# Importing the necessary libraries: 
# NumPy, SciPy (spatial algorithms), timing functions, a handler for csv files 
#
import numpy as np
import scipy.spatial as sp
import time
import csv

# %%
#
# Centering a point cloud A
#
def barycentered(A):
    #
    bar = np.sum(A, axis=1)/A.shape[1]
    #
    return np.array([vec - bar for vec in A.T]).T

# %%
#
# Best orthogonal fit between two (centred) labelled point clouds
#
# A and B are assumed to have the same number of points
#
def best_fit(A, B):
    #
    na = A.shape[1]
    nb = B.shape[1]
    #
    assert na==nb
    #
    H = A @ B.T
    W, S, V = np.linalg.svd(H)
    #
    return V.T @ W.T

# %%
#
# Detecting nearest neighbours between two unlabelled point coluds A and B
#
# Assumption: cardinality of A <= cardinality of B 
#
# Input: point clouds A, B
#
# Output: for each point of A a matching point of B, as a 0/1-matrix
#
def nearest_neighbours(A, B):
    #
    na = A.shape[1]
    nb = B.shape[1]
    #
    assert na <= nb
    #
    tree = sp.KDTree(A.T, leafsize=10, compact_nodes=True, copy_data=True, balanced_tree=True)
    #
    matching = []
    I = matrix.identity(na)
    #
    for i in range(nb):
        _, ind = tree.query(B.T[i], k=1, p=2, workers=-1)
        matching += [I[ind]]
    #    
    return np.array(matching)

# %%
#
# ICP algorithm for two unlabelled point clouds A and B
#
# Assumption: cardinality of A <= cardinality of B
#
# Input:
# A, B = unlabelled point clouds
# init = initial orthogonal transformation
# max_iter = maximum number of iterations
# tol = tolerance for halting the computation
#
# Output:
# U = orthogonal transformation bringing A to B as close as possible
# nn = nearest neighbor matching between U*A and B
# dist = distance between U*A*nn and B (in the max singular value norm)
#
def icp(A, B, init=None, max_iter=100, tol=1e-16):
    #
    src = copy(A)
    dst = copy(B)
    #
    na = src.shape[1]
    nb = src.shape[1]
    #
    assert na <= nb
    #
    if (init is not None):
        src = init @ src
    #    
    prev_err = 0
    #
    for i in range(max_iter):
        #   
        nn = nearest_neighbours(src, dst)
        U = best_fit(src, dst @ nn)
        #    
        src = U @ src
        #
        diff = src - dst @ nn
        err  = np.linalg.norm(diff, 2)
        #
        if abs(prev_err - err) < tol:
            break
        #    
        prev_err = err
    #
    U = best_fit(A, src)
    nn = nearest_neighbours(U @ A, dst)
    #
    diff = U @ A - B @ nn
    dist = np.linalg.norm(diff, 2)
    #
    return U, nn, dist

# %%
#
# Testing the Main Algorithm on the Caerbannog point clouds with 
# *additive* noise generated by the Gaussian N(0, \sigma^2)
#

# %%
#
# Raghupathi, Sunand; Brunhart-Lupo, Nicholas; Gruchalla, Kenny (2020)
# "Caerbannog Point Clouds". National Renewable Energy Laboratory. 10.7799/1729892
# Source: https://data.nrel.gov/submissions/153
#

# %%
#
# Testing the Algorithm a given point cloud P
# 
# Producing another point cloud Q0 = O * P * S, with O a random orthogonal transformation
# and S a random permutation. Then adding noise N with each entry being Gaussian with
# mean 0 and variance sigma2. Creating Q = Q0 + N.
#
# Test: determine the distance dist_spec from the recovered image of P denoted by 
# R = o * P * S to the specimen Q0, and compare it to the distance between d_icp 
# between o * P * s and Q returned by the ICP algorithm.
#
# Here it is important to note that S is a permutation, while s is a matching of nearest 
# neighbours in o * P and Q. The latter does not have to be a permutation matrix. 
#
def test_point_cloud(P, sigma2=0.01, tol=0.05, verbose=False):
    #
    dim = P.shape[0]
    num = P.shape[1]
    normP = np.linalg.norm(P, 2)
    if verbose:
        print("Number of points: {}".format(num))
    #
    Sym = SymmetricGroup(num)
    #
    seed = np.array([np.random.normal(0.0, 1.0) for _ in range(dim^2)]).reshape(dim,dim)
    O = np.linalg.qr(seed, mode='complete')[0]
    S = np.array(Sym.random_element().matrix())
    #
    P = barycentered(P)
    #
    Q0 = O @ P @ S
    N = np.array([[np.random.normal(0.0, sigma2) for i in range(num)] for j in range(dim)])
    Q = Q0 + N
    dist_noise = np.linalg.norm(N, 2) / normP
    if verbose:
        print("Noise introduced (normalised): {}".format(dist_noise))
    #
    Q = barycentered(Q)
    #
    Ep = P @ P.T
    Eigp, Up = np.linalg.eigh(Ep)
    #
    Eq = Q @ Q.T
    Eigq, Uq = np.linalg.eigh(Eq)
    #
    U0 = Uq @ Up.T
    #
    isoms_discrete = MatrixGroup([matrix.diagonal(d) for d in Permutations([-1]+[1]*(dim-1))])
    isoms_discrete = [np.array(matrix(m)) for m in isoms_discrete]
    #
    sols = []
    for isom in isoms_discrete:
        U = U0 @ Up @ isom @ Up.T
        nn = nearest_neighbours(U @ P, Q)
        diff_init = U @ P - Q @ nn
        d_init = np.linalg.norm(diff_init, 2) / normP
        sols += [(U, nn, d_init)]
    sols = sorted(sols, key=lambda x: x[2])
    o_init, s_init, dist_init = sols[0]
    o, s, d = icp(P, Q, o_init)
    dist_icp = d / normP
    delta_icp = dist_init - dist_icp
    diff = o_init - o
    delta_ortho_icp = np.linalg.norm(diff, 2)
    R = o @ P @ S
    diff = Q0 - R
    dist_spec = np.linalg.norm(diff, 2) / normP
    diff = o - O
    dist_ortho = np.linalg.norm(diff, 2)
    diff = s.T - S
    dist_per = np.linalg.norm(diff, 'fro')**2/(4*num)
    if verbose:
        print("Orthogonal transformation found:")
        print(o)
        print("Distance to the initial one:")
        print(dist_ortho)
        print("Nearest neighbour matching found:")
        print(s.T)
        print("Normalised Hamming distance to the initial permutation:")
        print(dist_per)
        print("Normalised distance to noisy image:")
        print(dist_icp)
        print("Actual distance to specimen (normalised):")
        print(dist_spec)
        print("ICP improvement (normalised):")
        print(delta_icp)
        print("ICP change to orthogonal transformation:")
        print(delta_ortho_icp)
    #
    flag = ( dist_spec < tol )
    #
    return flag, dist_noise, dist_icp, delta_icp, delta_ortho_icp,\
           dist_spec, dist_ortho, dist_per

# %%
#
# Running a given number of tests num_tests on a given point cloud 
# generated by calling test_random(dim, num, min_coord, max_coord)
#
# Some statistics is collected and printed as output
#
def run_tests_point_cloud(P, num_tests, sigma2=0.05, tol=0.05, verbose=False):
    #
    num_success = 0
    num_fail  = 0
    rec_dist_noise = []
    rec_dist_icp = []
    rec_delta_icp = []
    rec_delta_ortho_icp = []
    rec_dist_spec = []
    rec_dist_ortho = []
    rec_dist_per = []
    #
    start = time.process_time()
    #
    for i in range(num_tests):
        test_flag = False
        print("#"*16+" Test #{} ".format(i+1)+"#"*16)
        #
        test_flag, test_dist_noise, test_dist_icp, test_delta_icp,\
        test_delta_ortho_icp, test_dist_spec, test_dist_ortho,\
        test_dist_per = test_point_cloud(P, sigma2, tol, verbose)
        #
        rec_dist_noise += [test_dist_noise]
        rec_dist_icp += [test_dist_icp]
        rec_delta_icp += [test_delta_icp]
        rec_delta_ortho_icp += [test_delta_ortho_icp]
        rec_dist_spec += [test_dist_spec]
        rec_dist_ortho += [test_dist_ortho]
        rec_dist_per += [test_dist_per]
        if test_flag:
            print("SUCCESS")
            num_success += 1
        else:
            print("FAIL")
            num_fail += 1
        print("#"*42)
    #
    end = time.process_time()
    #
    assert (num_success + num_fail == num_tests)
    #
    avg_dist_noise = np.mean(rec_dist_noise)
    avg_dist_icp = np.mean(rec_dist_icp)
    avg_delta_icp = np.mean(rec_delta_icp)
    avg_delta_ortho_icp = np.mean(rec_delta_ortho_icp)
    avg_dist_spec = np.mean(rec_dist_spec)
    avg_dist_ortho = np.mean(rec_dist_ortho)
    avg_dist_per = np.mean(rec_dist_per)
    #
    print("Time elapsed:", time.strftime('%H:%M:%S', time.gmtime(end-start)))
    print("Success rate:", float(num_success/num_tests))
    print("======= Mean values =======")
    print("Added noise (normalised): {}".format(avg_dist_noise))
    print("Distance to noisy image (normalised): {}".format(avg_dist_icp))
    print("Distance to specimen (normalised): {}".format(avg_dist_spec))
    print("Distance to initial orthogonal transformation: {}".format(avg_dist_ortho))
    print("Hamming distance to initial permutation (normalised): {}".format(avg_dist_per))
    print("ICP improvement (normalised): {}".format(avg_delta_icp))
    print("ICP change to orthogonal transformation: {}".format(avg_delta_ortho_icp))

# %%
#
# The following unoclluded point clouds are used: teapot, bunny, cow. 
# The additive noise used is Gaussian N(0, 0.01) in which case most tests pass. 
#
filenames = ["Teapot.csv", "Bunny.csv", "Cow.csv"]
#
for name in filenames:
    #
    P = []
    #
    f = open(name)
    reader = csv.reader(f)
    #
    for line in reader:
        P += [[RDF(line[j]) for j in range(3)]]
    #    
    f.close()
    #    
    P = np.array(P).T
    #
    print("File read: {}".format(name))
    #
    run_tests_point_cloud(P, sigma2=0.01, num_tests=100, tol=0.05, verbose=False)
    #
    print("#"*42)
# Out:
# File read: Teapot.csv
# ################ Test #1 ################
# SUCCESS
# ##########################################
# ################ Test #2 ################
# SUCCESS
# ##########################################
# ################ Test #3 ################
# SUCCESS
# ##########################################
# ################ Test #4 ################
# SUCCESS
# ##########################################
# ################ Test #5 ################
# SUCCESS
# ##########################################
# ################ Test #6 ################
# SUCCESS
# ##########################################
# ################ Test #7 ################
# SUCCESS
# ##########################################
# ################ Test #8 ################
# SUCCESS
# ##########################################
# ################ Test #9 ################
# SUCCESS
# ##########################################
# ################ Test #10 ################
# SUCCESS
# ##########################################
# ################ Test #11 ################
# SUCCESS
# ##########################################
# ################ Test #12 ################
# SUCCESS
# ##########################################
# ################ Test #13 ################
# SUCCESS
# ##########################################
# ################ Test #14 ################
# SUCCESS
# ##########################################
# ################ Test #15 ################
# SUCCESS
# ##########################################
# ################ Test #16 ################
# SUCCESS
# ##########################################
# ################ Test #17 ################
# SUCCESS
# ##########################################
# ################ Test #18 ################
# SUCCESS
# ##########################################
# ################ Test #19 ################
# SUCCESS
# ##########################################
# ################ Test #20 ################
# SUCCESS
# ##########################################
# ################ Test #21 ################
# SUCCESS
# ##########################################
# ################ Test #22 ################
# SUCCESS
# ##########################################
# ################ Test #23 ################
# SUCCESS
# ##########################################
# ################ Test #24 ################
# SUCCESS
# ##########################################
# ################ Test #25 ################
# SUCCESS
# ##########################################
# ################ Test #26 ################
# SUCCESS
# ##########################################
# ################ Test #27 ################
# SUCCESS
# ##########################################
# ################ Test #28 ################
# SUCCESS
# ##########################################
# ################ Test #29 ################
# SUCCESS
# ##########################################
# ################ Test #30 ################
# SUCCESS
# ##########################################
# ################ Test #31 ################
# SUCCESS
# ##########################################
# ################ Test #32 ################
# SUCCESS
# ##########################################
# ################ Test #33 ################
# SUCCESS
# ##########################################
# ################ Test #34 ################
# SUCCESS
# ##########################################
# ################ Test #35 ################
# SUCCESS
# ##########################################
# ################ Test #36 ################
# SUCCESS
# ##########################################
# ################ Test #37 ################
# SUCCESS
# ##########################################
# ################ Test #38 ################
# SUCCESS
# ##########################################
# ################ Test #39 ################
# SUCCESS
# ##########################################
# ################ Test #40 ################
# SUCCESS
# ##########################################
# ################ Test #41 ################
# SUCCESS
# ##########################################
# ################ Test #42 ################
# SUCCESS
# ##########################################
# ################ Test #43 ################
# SUCCESS
# ##########################################
# ################ Test #44 ################
# SUCCESS
# ##########################################
# ################ Test #45 ################
# SUCCESS
# ##########################################
# ################ Test #46 ################
# SUCCESS
# ##########################################
# ################ Test #47 ################
# SUCCESS
# ##########################################
# ################ Test #48 ################
# SUCCESS
# ##########################################
# ################ Test #49 ################
# SUCCESS
# ##########################################
# ################ Test #50 ################
# SUCCESS
# ##########################################
# ################ Test #51 ################
# SUCCESS
# ##########################################
# ################ Test #52 ################
# SUCCESS
# ##########################################
# ################ Test #53 ################
# SUCCESS
# ##########################################
# ################ Test #54 ################
# SUCCESS
# ##########################################
# ################ Test #55 ################
# SUCCESS
# ##########################################
# ################ Test #56 ################
# SUCCESS
# ##########################################
# ################ Test #57 ################
# SUCCESS
# ##########################################
# ################ Test #58 ################
# SUCCESS
# ##########################################
# ################ Test #59 ################
# SUCCESS
# ##########################################
# ################ Test #60 ################
# SUCCESS
# ##########################################
# ################ Test #61 ################
# SUCCESS
# ##########################################
# ################ Test #62 ################
# SUCCESS
# ##########################################
# ################ Test #63 ################
# SUCCESS
# ##########################################
# ################ Test #64 ################
# SUCCESS
# ##########################################
# ################ Test #65 ################
# SUCCESS
# ##########################################
# ################ Test #66 ################
# SUCCESS
# ##########################################
# ################ Test #67 ################
# SUCCESS
# ##########################################
# ################ Test #68 ################
# SUCCESS
# ##########################################
# ################ Test #69 ################
# SUCCESS
# ##########################################
# ################ Test #70 ################
# SUCCESS
# ##########################################
# ################ Test #71 ################
# SUCCESS
# ##########################################
# ################ Test #72 ################
# SUCCESS
# ##########################################
# ################ Test #73 ################
# SUCCESS
# ##########################################
# ################ Test #74 ################
# SUCCESS
# ##########################################
# ################ Test #75 ################
# SUCCESS
# ##########################################
# ################ Test #76 ################
# SUCCESS
# ##########################################
# ################ Test #77 ################
# SUCCESS
# ##########################################
# ################ Test #78 ################
# SUCCESS
# ##########################################
# ################ Test #79 ################
# SUCCESS
# ##########################################
# ################ Test #80 ################
# SUCCESS
# ##########################################
# ################ Test #81 ################
# SUCCESS
# ##########################################
# ################ Test #82 ################
# SUCCESS
# ##########################################
# ################ Test #83 ################
# SUCCESS
# ##########################################
# ################ Test #84 ################
# SUCCESS
# ##########################################
# ################ Test #85 ################
# SUCCESS
# ##########################################
# ################ Test #86 ################
# SUCCESS
# ##########################################
# ################ Test #87 ################
# SUCCESS
# ##########################################
# ################ Test #88 ################
# SUCCESS
# ##########################################
# ################ Test #89 ################
# SUCCESS
# ##########################################
# ################ Test #90 ################
# SUCCESS
# ##########################################
# ################ Test #91 ################
# SUCCESS
# ##########################################
# ################ Test #92 ################
# SUCCESS
# ##########################################
# ################ Test #93 ################
# SUCCESS
# ##########################################
# ################ Test #94 ################
# SUCCESS
# ##########################################
# ################ Test #95 ################
# SUCCESS
# ##########################################
# ################ Test #96 ################
# SUCCESS
# ##########################################
# ################ Test #97 ################
# SUCCESS
# ##########################################
# ################ Test #98 ################
# SUCCESS
# ##########################################
# ################ Test #99 ################
# SUCCESS
# ##########################################
# ################ Test #100 ################
# SUCCESS
# ##########################################
# Time elapsed: 00:05:26
# Success rate: 1.0
# ======= Mean values =======
# Added noise (normalised): 0.07499666601079037
# Distance to noisy image (normalised): 0.7956974689674817
# Distance to specimen (normalised): 0.009513712791434942
# Distance to initial orthogonal transformation: 0.011227313920788691
# Hamming distance to initial permutation (normalised): 0.19777777777777775
# ICP improvement (normalised): 0.0033218715064471083
# ICP change to orthogonal transformation: 0.01593962935154971
# ##########################################
# File read: Bunny.csv
# ################ Test #1 ################
# SUCCESS
# ##########################################
# ################ Test #2 ################
# SUCCESS
# ##########################################
# ################ Test #3 ################
# SUCCESS
# ##########################################
# ################ Test #4 ################
# SUCCESS
# ##########################################
# ################ Test #5 ################
# SUCCESS
# ##########################################
# ################ Test #6 ################
# SUCCESS
# ##########################################
# ################ Test #7 ################
# SUCCESS
# ##########################################
# ################ Test #8 ################
# SUCCESS
# ##########################################
# ################ Test #9 ################
# SUCCESS
# ##########################################
# ################ Test #10 ################
# SUCCESS
# ##########################################
# ################ Test #11 ################
# SUCCESS
# ##########################################
# ################ Test #12 ################
# SUCCESS
# ##########################################
# ################ Test #13 ################
# SUCCESS
# ##########################################
# ################ Test #14 ################
# SUCCESS
# ##########################################
# ################ Test #15 ################
# SUCCESS
# ##########################################
# ################ Test #16 ################
# SUCCESS
# ##########################################
# ################ Test #17 ################
# SUCCESS
# ##########################################
# ################ Test #18 ################
# SUCCESS
# ##########################################
# ################ Test #19 ################
# SUCCESS
# ##########################################
# ################ Test #20 ################
# SUCCESS
# ##########################################
# ################ Test #21 ################
# SUCCESS
# ##########################################
# ################ Test #22 ################
# SUCCESS
# ##########################################
# ################ Test #23 ################
# SUCCESS
# ##########################################
# ################ Test #24 ################
# SUCCESS
# ##########################################
# ################ Test #25 ################
# SUCCESS
# ##########################################
# ################ Test #26 ################
# SUCCESS
# ##########################################
# ################ Test #27 ################
# SUCCESS
# ##########################################
# ################ Test #28 ################
# SUCCESS
# ##########################################
# ################ Test #29 ################
# SUCCESS
# ##########################################
# ################ Test #30 ################
# SUCCESS
# ##########################################
# ################ Test #31 ################
# SUCCESS
# ##########################################
# ################ Test #32 ################
# SUCCESS
# ##########################################
# ################ Test #33 ################
# SUCCESS
# ##########################################
# ################ Test #34 ################
# SUCCESS
# ##########################################
# ################ Test #35 ################
# SUCCESS
# ##########################################
# ################ Test #36 ################
# SUCCESS
# ##########################################
# ################ Test #37 ################
# SUCCESS
# ##########################################
# ################ Test #38 ################
# SUCCESS
# ##########################################
# ################ Test #39 ################
# SUCCESS
# ##########################################
# ################ Test #40 ################
# SUCCESS
# ##########################################
# ################ Test #41 ################
# SUCCESS
# ##########################################
# ################ Test #42 ################
# SUCCESS
# ##########################################
# ################ Test #43 ################
# SUCCESS
# ##########################################
# ################ Test #44 ################
# SUCCESS
# ##########################################
# ################ Test #45 ################
# SUCCESS
# ##########################################
# ################ Test #46 ################
# SUCCESS
# ##########################################
# ################ Test #47 ################
# SUCCESS
# ##########################################
# ################ Test #48 ################
# SUCCESS
# ##########################################
# ################ Test #49 ################
# SUCCESS
# ##########################################
# ################ Test #50 ################
# SUCCESS
# ##########################################
# ################ Test #51 ################
# SUCCESS
# ##########################################
# ################ Test #52 ################
# SUCCESS
# ##########################################
# ################ Test #53 ################
# SUCCESS
# ##########################################
# ################ Test #54 ################
# SUCCESS
# ##########################################
# ################ Test #55 ################
# SUCCESS
# ##########################################
# ################ Test #56 ################
# SUCCESS
# ##########################################
# ################ Test #57 ################
# SUCCESS
# ##########################################
# ################ Test #58 ################
# SUCCESS
# ##########################################
# ################ Test #59 ################
# SUCCESS
# ##########################################
# ################ Test #60 ################
# SUCCESS
# ##########################################
# ################ Test #61 ################
# SUCCESS
# ##########################################
# ################ Test #62 ################
# SUCCESS
# ##########################################
# ################ Test #63 ################
# SUCCESS
# ##########################################
# ################ Test #64 ################
# SUCCESS
# ##########################################
# ################ Test #65 ################
# SUCCESS
# ##########################################
# ################ Test #66 ################
# SUCCESS
# ##########################################
# ################ Test #67 ################
# SUCCESS
# ##########################################
# ################ Test #68 ################
# SUCCESS
# ##########################################
# ################ Test #69 ################
# SUCCESS
# ##########################################
# ################ Test #70 ################
# SUCCESS
# ##########################################
# ################ Test #71 ################
# SUCCESS
# ##########################################
# ################ Test #72 ################
# SUCCESS
# ##########################################
# ################ Test #73 ################
# SUCCESS
# ##########################################
# ################ Test #74 ################
# SUCCESS
# ##########################################
# ################ Test #75 ################
# SUCCESS
# ##########################################
# ################ Test #76 ################
# SUCCESS
# ##########################################
# ################ Test #77 ################
# SUCCESS
# ##########################################
# ################ Test #78 ################
# SUCCESS
# ##########################################
# ################ Test #79 ################
# SUCCESS
# ##########################################
# ################ Test #80 ################
# SUCCESS
# ##########################################
# ################ Test #81 ################
# SUCCESS
# ##########################################
# ################ Test #82 ################
# SUCCESS
# ##########################################
# ################ Test #83 ################
# SUCCESS
# ##########################################
# ################ Test #84 ################
# SUCCESS
# ##########################################
# ################ Test #85 ################
# SUCCESS
# ##########################################
# ################ Test #86 ################
# SUCCESS
# ##########################################
# ################ Test #87 ################
# SUCCESS
# ##########################################
# ################ Test #88 ################
# SUCCESS
# ##########################################
# ################ Test #89 ################
# SUCCESS
# ##########################################
# ################ Test #90 ################
# SUCCESS
# ##########################################
# ################ Test #91 ################
# SUCCESS
# ##########################################
# ################ Test #92 ################
# SUCCESS
# ##########################################
# ################ Test #93 ################
# SUCCESS
# ##########################################
# ################ Test #94 ################
# SUCCESS
# ##########################################
# ################ Test #95 ################
# SUCCESS
# ##########################################
# ################ Test #96 ################
# SUCCESS
# ##########################################
# ################ Test #97 ################
# SUCCESS
# ##########################################
# ################ Test #98 ################
# SUCCESS
# ##########################################
# ################ Test #99 ################
# SUCCESS
# ##########################################
# ################ Test #100 ################
# SUCCESS
# ##########################################
# Time elapsed: 00:12:33
# Success rate: 1.0
# ======= Mean values =======
# Added noise (normalised): 0.07634882369454131
# Distance to noisy image (normalised): 0.7577423445075209
# Distance to specimen (normalised): 0.007604290992801814
# Distance to initial orthogonal transformation: 0.008854987178105804
# Hamming distance to initial permutation (normalised): 0.19550189393939388
# ICP improvement (normalised): 0.0041759112185718985
# ICP change to orthogonal transformation: 0.016308921488719062
# ##########################################
# File read: Cow.csv
# ################ Test #1 ################
# SUCCESS
# ##########################################
# ################ Test #2 ################
# SUCCESS
# ##########################################
# ################ Test #3 ################
# SUCCESS
# ##########################################
# ################ Test #4 ################
# SUCCESS
# ##########################################
# ################ Test #5 ################
# SUCCESS
# ##########################################
# ################ Test #6 ################
# SUCCESS
# ##########################################
# ################ Test #7 ################
# SUCCESS
# ##########################################
# ################ Test #8 ################
# SUCCESS
# ##########################################
# ################ Test #9 ################
# SUCCESS
# ##########################################
# ################ Test #10 ################
# SUCCESS
# ##########################################
# ################ Test #11 ################
# SUCCESS
# ##########################################
# ################ Test #12 ################
# SUCCESS
# ##########################################
# ################ Test #13 ################
# SUCCESS
# ##########################################
# ################ Test #14 ################
# SUCCESS
# ##########################################
# ################ Test #15 ################
# SUCCESS
# ##########################################
# ################ Test #16 ################
# SUCCESS
# ##########################################
# ################ Test #17 ################
# SUCCESS
# ##########################################
# ################ Test #18 ################
# SUCCESS
# ##########################################
# ################ Test #19 ################
# SUCCESS
# ##########################################
# ################ Test #20 ################
# SUCCESS
# ##########################################
# ################ Test #21 ################
# SUCCESS
# ##########################################
# ################ Test #22 ################
# SUCCESS
# ##########################################
# ################ Test #23 ################
# SUCCESS
# ##########################################
# ################ Test #24 ################
# SUCCESS
# ##########################################
# ################ Test #25 ################
# SUCCESS
# ##########################################
# ################ Test #26 ################
# SUCCESS
# ##########################################
# ################ Test #27 ################
# SUCCESS
# ##########################################
# ################ Test #28 ################
# SUCCESS
# ##########################################
# ################ Test #29 ################
# SUCCESS
# ##########################################
# ################ Test #30 ################
# SUCCESS
# ##########################################
# ################ Test #31 ################
# SUCCESS
# ##########################################
# ################ Test #32 ################
# SUCCESS
# ##########################################
# ################ Test #33 ################
# SUCCESS
# ##########################################
# ################ Test #34 ################
# SUCCESS
# ##########################################
# ################ Test #35 ################
# SUCCESS
# ##########################################
# ################ Test #36 ################
# SUCCESS
# ##########################################
# ################ Test #37 ################
# SUCCESS
# ##########################################
# ################ Test #38 ################
# SUCCESS
# ##########################################
# ################ Test #39 ################
# SUCCESS
# ##########################################
# ################ Test #40 ################
# SUCCESS
# ##########################################
# ################ Test #41 ################
# SUCCESS
# ##########################################
# ################ Test #42 ################
# SUCCESS
# ##########################################
# ################ Test #43 ################
# SUCCESS
# ##########################################
# ################ Test #44 ################
# SUCCESS
# ##########################################
# ################ Test #45 ################
# SUCCESS
# ##########################################
# ################ Test #46 ################
# SUCCESS
# ##########################################
# ################ Test #47 ################
# SUCCESS
# ##########################################
# ################ Test #48 ################
# SUCCESS
# ##########################################
# ################ Test #49 ################
# SUCCESS
# ##########################################
# ################ Test #50 ################
# SUCCESS
# ##########################################
# ################ Test #51 ################
# SUCCESS
# ##########################################
# ################ Test #52 ################
# SUCCESS
# ##########################################
# ################ Test #53 ################
# SUCCESS
# ##########################################
# ################ Test #54 ################
# SUCCESS
# ##########################################
# ################ Test #55 ################
# SUCCESS
# ##########################################
# ################ Test #56 ################
# SUCCESS
# ##########################################
# ################ Test #57 ################
# SUCCESS
# ##########################################
# ################ Test #58 ################
# SUCCESS
# ##########################################
# ################ Test #59 ################
# SUCCESS
# ##########################################
# ################ Test #60 ################
# SUCCESS
# ##########################################
# ################ Test #61 ################
# SUCCESS
# ##########################################
# ################ Test #62 ################
# SUCCESS
# ##########################################
# ################ Test #63 ################
# SUCCESS
# ##########################################
# ################ Test #64 ################
# SUCCESS
# ##########################################
# ################ Test #65 ################
# SUCCESS
# ##########################################
# ################ Test #66 ################
# SUCCESS
# ##########################################
# ################ Test #67 ################
# SUCCESS
# ##########################################
# ################ Test #68 ################
# SUCCESS
# ##########################################
# ################ Test #69 ################
# SUCCESS
# ##########################################
# ################ Test #70 ################
# SUCCESS
# ##########################################
# ################ Test #71 ################
# SUCCESS
# ##########################################
# ################ Test #72 ################
# SUCCESS
# ##########################################
# ################ Test #73 ################
# SUCCESS
# ##########################################
# ################ Test #74 ################
# SUCCESS
# ##########################################
# ################ Test #75 ################
# SUCCESS
# ##########################################
# ################ Test #76 ################
# SUCCESS
# ##########################################
# ################ Test #77 ################
# SUCCESS
# ##########################################
# ################ Test #78 ################
# SUCCESS
# ##########################################
# ################ Test #79 ################
# SUCCESS
# ##########################################
# ################ Test #80 ################
# SUCCESS
# ##########################################
# ################ Test #81 ################
# SUCCESS
# ##########################################
# ################ Test #82 ################
# SUCCESS
# ##########################################
# ################ Test #83 ################
# SUCCESS
# ##########################################
# ################ Test #84 ################
# SUCCESS
# ##########################################
# ################ Test #85 ################
# SUCCESS
# ##########################################
# ################ Test #86 ################
# SUCCESS
# ##########################################
# ################ Test #87 ################
# SUCCESS
# ##########################################
# ################ Test #88 ################
# SUCCESS
# ##########################################
# ################ Test #89 ################
# SUCCESS
# ##########################################
# ################ Test #90 ################
# SUCCESS
# ##########################################
# ################ Test #91 ################
# SUCCESS
# ##########################################
# ################ Test #92 ################
# SUCCESS
# ##########################################
# ################ Test #93 ################
# SUCCESS
# ##########################################
# ################ Test #94 ################
# SUCCESS
# ##########################################
# ################ Test #95 ################
# SUCCESS
# ##########################################
# ################ Test #96 ################
# SUCCESS
# ##########################################
# ################ Test #97 ################
# SUCCESS
# ##########################################
# ################ Test #98 ################
# SUCCESS
# ##########################################
# ################ Test #99 ################
# SUCCESS
# ##########################################
# ################ Test #100 ################
# SUCCESS
# ##########################################
# Time elapsed: 00:15:42
# Success rate: 1.0
# ======= Mean values =======
# Added noise (normalised): 0.05674107511196266
# Distance to noisy image (normalised): 0.9200044567927548
# Distance to specimen (normalised): 0.005319375881976975
# Distance to initial orthogonal transformation: 0.007977055090224384
# Hamming distance to initial permutation (normalised): 0.3076827242524917
# ICP improvement (normalised): -0.0009226087167168374
# ICP change to orthogonal transformation: 0.007653479083782628
# ##########################################

# %%
#
# The following unoclluded point clouds are used: teapot, bunny, cow. 
# The additive noise used is Gaussian N(0, 0.06) in which case most tests fail. 
#
filenames = ["Teapot.csv", "Bunny.csv", "Cow.csv"]
#
for name in filenames:
    #
    P = []
    #
    f = open(name)
    reader = csv.reader(f)
    #
    for line in reader:
        P += [[RDF(line[j]) for j in range(3)]]
    #    
    f.close()
    #    
    P = np.array(P).T
    #
    print("File read: {}".format(name))
    #
    run_tests_point_cloud(P, sigma2=0.06, num_tests=100, tol=0.05, verbose=False)
    #
    print("#"*42)
# Out:
# File read: Teapot.csv
# ################ Test #1 ################
# FAIL
# ##########################################
# ################ Test #2 ################
# FAIL
# ##########################################
# ################ Test #3 ################
# FAIL
# ##########################################
# ################ Test #4 ################
# FAIL
# ##########################################
# ################ Test #5 ################
# FAIL
# ##########################################
# ################ Test #6 ################
# SUCCESS
# ##########################################
# ################ Test #7 ################
# FAIL
# ##########################################
# ################ Test #8 ################
# FAIL
# ##########################################
# ################ Test #9 ################
# FAIL
# ##########################################
# ################ Test #10 ################
# FAIL
# ##########################################
# ################ Test #11 ################
# FAIL
# ##########################################
# ################ Test #12 ################
# FAIL
# ##########################################
# ################ Test #13 ################
# FAIL
# ##########################################
# ################ Test #14 ################
# FAIL
# ##########################################
# ################ Test #15 ################
# FAIL
# ##########################################
# ################ Test #16 ################
# FAIL
# ##########################################
# ################ Test #17 ################
# FAIL
# ##########################################
# ################ Test #18 ################
# FAIL
# ##########################################
# ################ Test #19 ################
# FAIL
# ##########################################
# ################ Test #20 ################
# FAIL
# ##########################################
# ################ Test #21 ################
# FAIL
# ##########################################
# ################ Test #22 ################
# FAIL
# ##########################################
# ################ Test #23 ################
# FAIL
# ##########################################
# ################ Test #24 ################
# FAIL
# ##########################################
# ################ Test #25 ################
# FAIL
# ##########################################
# ################ Test #26 ################
# FAIL
# ##########################################
# ################ Test #27 ################
# FAIL
# ##########################################
# ################ Test #28 ################
# FAIL
# ##########################################
# ################ Test #29 ################
# FAIL
# ##########################################
# ################ Test #30 ################
# FAIL
# ##########################################
# ################ Test #31 ################
# FAIL
# ##########################################
# ################ Test #32 ################
# FAIL
# ##########################################
# ################ Test #33 ################
# FAIL
# ##########################################
# ################ Test #34 ################
# FAIL
# ##########################################
# ################ Test #35 ################
# FAIL
# ##########################################
# ################ Test #36 ################
# FAIL
# ##########################################
# ################ Test #37 ################
# FAIL
# ##########################################
# ################ Test #38 ################
# FAIL
# ##########################################
# ################ Test #39 ################
# FAIL
# ##########################################
# ################ Test #40 ################
# FAIL
# ##########################################
# ################ Test #41 ################
# FAIL
# ##########################################
# ################ Test #42 ################
# FAIL
# ##########################################
# ################ Test #43 ################
# FAIL
# ##########################################
# ################ Test #44 ################
# FAIL
# ##########################################
# ################ Test #45 ################
# FAIL
# ##########################################
# ################ Test #46 ################
# FAIL
# ##########################################
# ################ Test #47 ################
# FAIL
# ##########################################
# ################ Test #48 ################
# FAIL
# ##########################################
# ################ Test #49 ################
# FAIL
# ##########################################
# ################ Test #50 ################
# FAIL
# ##########################################
# ################ Test #51 ################
# FAIL
# ##########################################
# ################ Test #52 ################
# FAIL
# ##########################################
# ################ Test #53 ################
# FAIL
# ##########################################
# ################ Test #54 ################
# FAIL
# ##########################################
# ################ Test #55 ################
# FAIL
# ##########################################
# ################ Test #56 ################
# SUCCESS
# ##########################################
# ################ Test #57 ################
# FAIL
# ##########################################
# ################ Test #58 ################
# FAIL
# ##########################################
# ################ Test #59 ################
# FAIL
# ##########################################
# ################ Test #60 ################
# SUCCESS
# ##########################################
# ################ Test #61 ################
# FAIL
# ##########################################
# ################ Test #62 ################
# FAIL
# ##########################################
# ################ Test #63 ################
# FAIL
# ##########################################
# ################ Test #64 ################
# FAIL
# ##########################################
# ################ Test #65 ################
# FAIL
# ##########################################
# ################ Test #66 ################
# FAIL
# ##########################################
# ################ Test #67 ################
# FAIL
# ##########################################
# ################ Test #68 ################
# FAIL
# ##########################################
# ################ Test #69 ################
# FAIL
# ##########################################
# ################ Test #70 ################
# FAIL
# ##########################################
# ################ Test #71 ################
# FAIL
# ##########################################
# ################ Test #72 ################
# FAIL
# ##########################################
# ################ Test #73 ################
# FAIL
# ##########################################
# ################ Test #74 ################
# FAIL
# ##########################################
# ################ Test #75 ################
# FAIL
# ##########################################
# ################ Test #76 ################
# SUCCESS
# ##########################################
# ################ Test #77 ################
# FAIL
# ##########################################
# ################ Test #78 ################
# FAIL
# ##########################################
# ################ Test #79 ################
# FAIL
# ##########################################
# ################ Test #80 ################
# FAIL
# ##########################################
# ################ Test #81 ################
# SUCCESS
# ##########################################
# ################ Test #82 ################
# FAIL
# ##########################################
# ################ Test #83 ################
# SUCCESS
# ##########################################
# ################ Test #84 ################
# FAIL
# ##########################################
# ################ Test #85 ################
# FAIL
# ##########################################
# ################ Test #86 ################
# FAIL
# ##########################################
# ################ Test #87 ################
# FAIL
# ##########################################
# ################ Test #88 ################
# FAIL
# ##########################################
# ################ Test #89 ################
# FAIL
# ##########################################
# ################ Test #90 ################
# FAIL
# ##########################################
# ################ Test #91 ################
# FAIL
# ##########################################
# ################ Test #92 ################
# FAIL
# ##########################################
# ################ Test #93 ################
# FAIL
# ##########################################
# ################ Test #94 ################
# FAIL
# ##########################################
# ################ Test #95 ################
# FAIL
# ##########################################
# ################ Test #96 ################
# FAIL
# ##########################################
# ################ Test #97 ################
# FAIL
# ##########################################
# ################ Test #98 ################
# FAIL
# ##########################################
# ################ Test #99 ################
# FAIL
# ##########################################
# ################ Test #100 ################
# FAIL
# ##########################################
# Time elapsed: 00:08:40
# Success rate: 0.06
# ======= Mean values =======
# Added noise (normalised): 0.45189576584974595
# Distance to noisy image (normalised): 1.2626634918118202
# Distance to specimen (normalised): 0.985981624485534
# Distance to initial orthogonal transformation: 1.1640756129640675
# Hamming distance to initial permutation (normalised): 0.4872649572649573
# ICP improvement (normalised): -0.03638220919151321
# ICP change to orthogonal transformation: 0.1066528279738958
# ##########################################
# File read: Bunny.csv
# ################ Test #1 ################
# FAIL
# ##########################################
# ################ Test #2 ################
# FAIL
# ##########################################
# ################ Test #3 ################
# SUCCESS
# ##########################################
# ################ Test #4 ################
# FAIL
# ##########################################
# ################ Test #5 ################
# FAIL
# ##########################################
# ################ Test #6 ################
# FAIL
# ##########################################
# ################ Test #7 ################
# FAIL
# ##########################################
# ################ Test #8 ################
# FAIL
# ##########################################
# ################ Test #9 ################
# FAIL
# ##########################################
# ################ Test #10 ################
# SUCCESS
# ##########################################
# ################ Test #11 ################
# FAIL
# ##########################################
# ################ Test #12 ################
# FAIL
# ##########################################
# ################ Test #13 ################
# SUCCESS
# ##########################################
# ################ Test #14 ################
# SUCCESS
# ##########################################
# ################ Test #15 ################
# FAIL
# ##########################################
# ################ Test #16 ################
# FAIL
# ##########################################
# ################ Test #17 ################
# FAIL
# ##########################################
# ################ Test #18 ################
# FAIL
# ##########################################
# ################ Test #19 ################
# FAIL
# ##########################################
# ################ Test #20 ################
# FAIL
# ##########################################
# ################ Test #21 ################
# SUCCESS
# ##########################################
# ################ Test #22 ################
# FAIL
# ##########################################
# ################ Test #23 ################
# FAIL
# ##########################################
# ################ Test #24 ################
# FAIL
# ##########################################
# ################ Test #25 ################
# FAIL
# ##########################################
# ################ Test #26 ################
# FAIL
# ##########################################
# ################ Test #27 ################
# FAIL
# ##########################################
# ################ Test #28 ################
# FAIL
# ##########################################
# ################ Test #29 ################
# FAIL
# ##########################################
# ################ Test #30 ################
# FAIL
# ##########################################
# ################ Test #31 ################
# FAIL
# ##########################################
# ################ Test #32 ################
# FAIL
# ##########################################
# ################ Test #33 ################
# FAIL
# ##########################################
# ################ Test #34 ################
# FAIL
# ##########################################
# ################ Test #35 ################
# SUCCESS
# ##########################################
# ################ Test #36 ################
# FAIL
# ##########################################
# ################ Test #37 ################
# FAIL
# ##########################################
# ################ Test #38 ################
# FAIL
# ##########################################
# ################ Test #39 ################
# FAIL
# ##########################################
# ################ Test #40 ################
# FAIL
# ##########################################
# ################ Test #41 ################
# FAIL
# ##########################################
# ################ Test #42 ################
# FAIL
# ##########################################
# ################ Test #43 ################
# FAIL
# ##########################################
# ################ Test #44 ################
# FAIL
# ##########################################
# ################ Test #45 ################
# FAIL
# ##########################################
# ################ Test #46 ################
# FAIL
# ##########################################
# ################ Test #47 ################
# FAIL
# ##########################################
# ################ Test #48 ################
# FAIL
# ##########################################
# ################ Test #49 ################
# FAIL
# ##########################################
# ################ Test #50 ################
# FAIL
# ##########################################
# ################ Test #51 ################
# FAIL
# ##########################################
# ################ Test #52 ################
# FAIL
# ##########################################
# ################ Test #53 ################
# FAIL
# ##########################################
# ################ Test #54 ################
# SUCCESS
# ##########################################
# ################ Test #55 ################
# FAIL
# ##########################################
# ################ Test #56 ################
# FAIL
# ##########################################
# ################ Test #57 ################
# FAIL
# ##########################################
# ################ Test #58 ################
# FAIL
# ##########################################
# ################ Test #59 ################
# FAIL
# ##########################################
# ################ Test #60 ################
# FAIL
# ##########################################
# ################ Test #61 ################
# FAIL
# ##########################################
# ################ Test #62 ################
# FAIL
# ##########################################
# ################ Test #63 ################
# FAIL
# ##########################################
# ################ Test #64 ################
# FAIL
# ##########################################
# ################ Test #65 ################
# FAIL
# ##########################################
# ################ Test #66 ################
# FAIL
# ##########################################
# ################ Test #67 ################
# FAIL
# ##########################################
# ################ Test #68 ################
# SUCCESS
# ##########################################
# ################ Test #69 ################
# FAIL
# ##########################################
# ################ Test #70 ################
# FAIL
# ##########################################
# ################ Test #71 ################
# FAIL
# ##########################################
# ################ Test #72 ################
# FAIL
# ##########################################
# ################ Test #73 ################
# FAIL
# ##########################################
# ################ Test #74 ################
# FAIL
# ##########################################
# ################ Test #75 ################
# FAIL
# ##########################################
# ################ Test #76 ################
# FAIL
# ##########################################
# ################ Test #77 ################
# FAIL
# ##########################################
# ################ Test #78 ################
# SUCCESS
# ##########################################
# ################ Test #79 ################
# FAIL
# ##########################################
# ################ Test #80 ################
# FAIL
# ##########################################
# ################ Test #81 ################
# FAIL
# ##########################################
# ################ Test #82 ################
# FAIL
# ##########################################
# ################ Test #83 ################
# FAIL
# ##########################################
# ################ Test #84 ################
# FAIL
# ##########################################
# ################ Test #85 ################
# FAIL
# ##########################################
# ################ Test #86 ################
# FAIL
# ##########################################
# ################ Test #87 ################
# FAIL
# ##########################################
# ################ Test #88 ################
# FAIL
# ##########################################
# ################ Test #89 ################
# FAIL
# ##########################################
# ################ Test #90 ################
# FAIL
# ##########################################
# ################ Test #91 ################
# FAIL
# ##########################################
# ################ Test #92 ################
# FAIL
# ##########################################
# ################ Test #93 ################
# FAIL
# ##########################################
# ################ Test #94 ################
# FAIL
# ##########################################
# ################ Test #95 ################
# SUCCESS
# ##########################################
# ################ Test #96 ################
# FAIL
# ##########################################
# ################ Test #97 ################
# FAIL
# ##########################################
# ################ Test #98 ################
# SUCCESS
# ##########################################
# ################ Test #99 ################
# FAIL
# ##########################################
# ################ Test #100 ################
# FAIL
# ##########################################
# Time elapsed: 00:23:23
# Success rate: 0.11
# ======= Mean values =======
# Added noise (normalised): 0.45713017811721857
# Distance to noisy image (normalised): 1.235230485588701
# Distance to specimen (normalised): 0.5962368759418082
# Distance to initial orthogonal transformation: 0.6724014545882241
# Hamming distance to initial permutation (normalised): 0.48640151515151525
# ICP improvement (normalised): -0.029401579806278527
# ICP change to orthogonal transformation: 0.11321355980992986
# ##########################################
# File read: Cow.csv
# ################ Test #1 ################
# FAIL
# ##########################################
# ################ Test #2 ################
# FAIL
# ##########################################
# ################ Test #3 ################
# SUCCESS
# ##########################################
# ################ Test #4 ################
# SUCCESS
# ##########################################
# ################ Test #5 ################
# SUCCESS
# ##########################################
# ################ Test #6 ################
# SUCCESS
# ##########################################
# ################ Test #7 ################
# FAIL
# ##########################################
# ################ Test #8 ################
# FAIL
# ##########################################
# ################ Test #9 ################
# FAIL
# ##########################################
# ################ Test #10 ################
# SUCCESS
# ##########################################
# ################ Test #11 ################
# FAIL
# ##########################################
# ################ Test #12 ################
# FAIL
# ##########################################
# ################ Test #13 ################
# FAIL
# ##########################################
# ################ Test #14 ################
# FAIL
# ##########################################
# ################ Test #15 ################
# FAIL
# ##########################################
# ################ Test #16 ################
# FAIL
# ##########################################
# ################ Test #17 ################
# FAIL
# ##########################################
# ################ Test #18 ################
# FAIL
# ##########################################
# ################ Test #19 ################
# FAIL
# ##########################################
# ################ Test #20 ################
# SUCCESS
# ##########################################
# ################ Test #21 ################
# FAIL
# ##########################################
# ################ Test #22 ################
# FAIL
# ##########################################
# ################ Test #23 ################
# FAIL
# ##########################################
# ################ Test #24 ################
# FAIL
# ##########################################
# ################ Test #25 ################
# SUCCESS
# ##########################################
# ################ Test #26 ################
# FAIL
# ##########################################
# ################ Test #27 ################
# SUCCESS
# ##########################################
# ################ Test #28 ################
# FAIL
# ##########################################
# ################ Test #29 ################
# FAIL
# ##########################################
# ################ Test #30 ################
# FAIL
# ##########################################
# ################ Test #31 ################
# SUCCESS
# ##########################################
# ################ Test #32 ################
# FAIL
# ##########################################
# ################ Test #33 ################
# FAIL
# ##########################################
# ################ Test #34 ################
# SUCCESS
# ##########################################
# ################ Test #35 ################
# FAIL
# ##########################################
# ################ Test #36 ################
# SUCCESS
# ##########################################
# ################ Test #37 ################
# FAIL
# ##########################################
# ################ Test #38 ################
# FAIL
# ##########################################
# ################ Test #39 ################
# FAIL
# ##########################################
# ################ Test #40 ################
# FAIL
# ##########################################
# ################ Test #41 ################
# FAIL
# ##########################################
# ################ Test #42 ################
# FAIL
# ##########################################
# ################ Test #43 ################
# FAIL
# ##########################################
# ################ Test #44 ################
# FAIL
# ##########################################
# ################ Test #45 ################
# FAIL
# ##########################################
# ################ Test #46 ################
# SUCCESS
# ##########################################
# ################ Test #47 ################
# FAIL
# ##########################################
# ################ Test #48 ################
# FAIL
# ##########################################
# ################ Test #49 ################
# FAIL
# ##########################################
# ################ Test #50 ################
# FAIL
# ##########################################
# ################ Test #51 ################
# SUCCESS
# ##########################################
# ################ Test #52 ################
# FAIL
# ##########################################
# ################ Test #53 ################
# SUCCESS
# ##########################################
# ################ Test #54 ################
# FAIL
# ##########################################
# ################ Test #55 ################
# FAIL
# ##########################################
# ################ Test #56 ################
# FAIL
# ##########################################
# ################ Test #57 ################
# FAIL
# ##########################################
# ################ Test #58 ################
# FAIL
# ##########################################
# ################ Test #59 ################
# FAIL
# ##########################################
# ################ Test #60 ################
# SUCCESS
# ##########################################
# ################ Test #61 ################
# FAIL
# ##########################################
# ################ Test #62 ################
# FAIL
# ##########################################
# ################ Test #63 ################
# FAIL
# ##########################################
# ################ Test #64 ################
# FAIL
# ##########################################
# ################ Test #65 ################
# SUCCESS
# ##########################################
# ################ Test #66 ################
# SUCCESS
# ##########################################
# ################ Test #67 ################
# SUCCESS
# ##########################################
# ################ Test #68 ################
# FAIL
# ##########################################
# ################ Test #69 ################
# FAIL
# ##########################################
# ################ Test #70 ################
# FAIL
# ##########################################
# ################ Test #71 ################
# SUCCESS
# ##########################################
# ################ Test #72 ################
# FAIL
# ##########################################
# ################ Test #73 ################
# FAIL
# ##########################################
# ################ Test #74 ################
# FAIL
# ##########################################
# ################ Test #75 ################
# FAIL
# ##########################################
# ################ Test #76 ################
# SUCCESS
# ##########################################
# ################ Test #77 ################
# FAIL
# ##########################################
# ################ Test #78 ################
# SUCCESS
# ##########################################
# ################ Test #79 ################
# FAIL
# ##########################################
# ################ Test #80 ################
# FAIL
# ##########################################
# ################ Test #81 ################
# FAIL
# ##########################################
# ################ Test #82 ################
# FAIL
# ##########################################
# ################ Test #83 ################
# SUCCESS
# ##########################################
# ################ Test #84 ################
# FAIL
# ##########################################
# ################ Test #85 ################
# SUCCESS
# ##########################################
# ################ Test #86 ################
# SUCCESS
# ##########################################
# ################ Test #87 ################
# FAIL
# ##########################################
# ################ Test #88 ################
# FAIL
# ##########################################
# ################ Test #89 ################
# FAIL
# ##########################################
# ################ Test #90 ################
# SUCCESS
# ##########################################
# ################ Test #91 ################
# SUCCESS
# ##########################################
# ################ Test #92 ################
# FAIL
# ##########################################
# ################ Test #93 ################
# SUCCESS
# ##########################################
# ################ Test #94 ################
# FAIL
# ##########################################
# ################ Test #95 ################
# SUCCESS
# ##########################################
# ################ Test #96 ################
# FAIL
# ##########################################
# ################ Test #97 ################
# FAIL
# ##########################################
# ################ Test #98 ################
# FAIL
# ##########################################
# ################ Test #99 ################
# FAIL
# ##########################################
# ################ Test #100 ################
# FAIL
# ##########################################
# Time elapsed: 00:21:33
# Success rate: 0.28
# ======= Mean values =======
# Added noise (normalised): 0.33952691631199167
# Distance to noisy image (normalised): 1.7553656312155714
# Distance to specimen (normalised): 0.5688695836362109
# Distance to initial orthogonal transformation: 1.3413418133871104
# Hamming distance to initial permutation (normalised): 0.49297342192691035
# ICP improvement (normalised): -0.0782517541650607
# ICP change to orthogonal transformation: 0.08289792069002047
# ##########################################

# %%
#
# Running a given number of tests num_tests on a given point cloud
#
# Output is then used to plot graphs of test stats
#
def point_cloud_stats(P, num_tests, sigma2=0.01, tol=0.05):
    #
    num_success = 0
    num_fail  = 0
    rec_dist_noise = []
    rec_dist_icp = []
    rec_delta_icp = []
    rec_delta_ortho_icp = []
    rec_dist_spec = []
    rec_dist_ortho = []
    rec_dist_per = []
    #
    start = time.process_time()
    #
    for i in range(num_tests):
        test_flag = False
        #
        test_flag, test_dist_noise, test_dist_icp, test_delta_icp,\
        test_delta_ortho_icp, test_dist_spec, test_dist_ortho,\
        test_dist_per = test_point_cloud(P, sigma2, tol, verbose=False)
        #
        rec_dist_noise += [test_dist_noise]
        rec_dist_icp += [test_dist_icp]
        rec_delta_icp += [test_delta_icp]
        rec_delta_ortho_icp += [test_delta_ortho_icp]
        rec_dist_spec += [test_dist_spec]
        rec_dist_ortho += [test_dist_ortho]
        rec_dist_per += [test_dist_per]
        if test_flag:
            num_success += 1
        else:
            num_fail += 1
    #
    end = time.process_time()
    #
    assert (num_success + num_fail == num_tests)
    #
    success_rate = float(num_success/num_tests)
    avg_dist_noise = np.mean(rec_dist_noise)
    avg_dist_icp = np.mean(rec_dist_icp)
    avg_delta_icp = np.mean(rec_delta_icp)
    avg_delta_ortho_icp = np.mean(rec_delta_ortho_icp)
    avg_dist_spec = np.mean(rec_dist_spec)
    avg_dist_ortho = np.mean(rec_dist_ortho)
    avg_dist_per = np.mean(rec_dist_per)
    #
    return success_rate, avg_dist_noise, avg_dist_icp, avg_delta_icp, avg_delta_ortho_icp,\
           avg_dist_spec, avg_dist_ortho, avg_dist_per

# %%
#
# Produces data for plotting test stats
#
def plot_point_cloud_stats(P, num_tests, sigma2array, tol=0.05):
    stats = []
    for sigma2 in sigma2array:
        test_stats = point_cloud_stats(P, num_tests, sigma2, tol)
        test_stats = (sigma2,) + test_stats
        stats += [test_stats]
    return stats

# %%
#
# The following unoclluded point clouds are used: teapot, bunny, cow. 
#
# The multiplicative noise used is Gaussian N(1, sigma2) with sigma2 
# taking consecutive values in [0.01, 0.02, ..., 0.06]. 
#
#
filenames = ["Teapot.csv", "Bunny.csv", "Cow.csv"]
data = []
#
for name in filenames:
    #
    P = []
    #
    f = open(name)
    reader = csv.reader(f)
    #
    for line in reader:
        P += [[RDF(line[j]) for j in range(3)]]
    #   
    f.close()
    #    
    P = np.array(P).T
    #
    print("File read: {}".format(name))
    #
    plt = plot_point_cloud_stats(P, num_tests=100, sigma2array=np.arange(0.01,0.07,0.01), tol=0.05)
    data += [(name, plt)]
    #
    print("Test stats produced ...")
# Out:
# File read: Teapot.csv
# Test stats produced ...
# File read: Bunny.csv
# Test stats produced ...
# File read: Cow.csv
# Test stats produced ...

# %%
#
# Test stats prduced have the following structure:
#
# data[_][0] : cloud file name = Teapot.csv, Bunny.csv, or Cow.csv
#
# data[_][1] = stats : test stats where stats[i] stands for
#
# i=0: sigma2,
# i=1: success_rate, 
# i=2: avg_dist_noise, 
# i=3: avg_dist_icp, 
# i=4: avg_delta_icp, 
# i=5: avg_delta_ortho_icp,
# i=6: avg_dist_spec, 
# i=7: avg_dist_ortho, 
# i=8: avg_dist_per
#

# %%
#
# success rate depending on (normalised) noise added
#
# Teapot = circle / red
# Bunny = square / green
# Cow = lozenge / blue
#
img = []
for entry in zip(data, [('o', 'red'), ('s', 'green'), ('d', 'blue')]):
    pic, mark = entry
    print(pic[0])
    stats = pic[1]
    img += [scatter_plot([(s[2],s[1]) for s in stats], marker=mark[0], markersize=50, facecolor=mark[1], edgecolor=None, xmin=0.0, ymin=0)]
    img += [polygon([(s[2],0.0), (s[2],s[1])], color=mark[1], thickness=1, xmin=0.0, ymin=0) for s in stats]
img = sum(img)
img.set_aspect_ratio('automatic')
img.plot().show()
# Out:
# Teapot.csv
# Bunny.csv
# Cow.csv
# Graphics object consisting of 21 graphics primitives

# %%
#
# distance to specimen depending on (normalised) noise added
#
# Teapot = circle / red
# Bunny = square / green
# Cow = lozenge / blue
#
img = []
for entry in zip(data, [('o', 'red'), ('s', 'green'), ('d', 'blue')]):
    pic, mark = entry
    print(pic[0])
    stats = pic[1]
    img += [scatter_plot([(s[2],s[6]) for s in stats], marker=mark[0], markersize=50, facecolor=mark[1], edgecolor=None, xmin=0.0, ymin=0)]
    img += [polygon([(s[2],0.0), (s[2],s[6])], color=mark[1], thickness=1, xmin=0.0, ymin=0) for s in stats]
img = sum(img)
img.set_aspect_ratio('automatic')
img.plot().show()
# Out:
# Teapot.csv
# Bunny.csv
# Cow.csv
# Graphics object consisting of 21 graphics primitives

# %%
#
# distance to initial orthogonal transformation depending on (normalised) noise added
#
# Teapot = circle / red
# Bunny = square / green
# Cow = lozenge / blue
#
img = []
for entry in zip(data, [('o', 'red'), ('s', 'green'), ('d', 'blue')]):
    pic, mark = entry
    print(pic[0])
    stats = pic[1]
    img += [scatter_plot([(s[2],s[7]) for s in stats], marker=mark[0], markersize=50, facecolor=mark[1], edgecolor=None, xmin=0.0, ymin=0)]
    img += [polygon([(s[2],0.0), (s[2],s[7])], color=mark[1], thickness=1, xmin=0.0, ymin=0) for s in stats]
img = sum(img)
img.set_aspect_ratio('automatic')
img.plot().show()
# Out:
# Teapot.csv
# Bunny.csv
# Cow.csv
# Graphics object consisting of 21 graphics primitives
